# %% [markdown]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
# !pip install --upgrade --force-reinstall --no-cache-dir --no-deps unsloth unsloth_zoo

# !pip install -U bitsandbytes

# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps trl peft accelerate bitsandbytes

# !wget -qO- https://raw.githubusercontent.com/unslothai/unsloth/main/unsloth/_auto_install.py | python -

# %% [markdown]
# شغال

# %%
import transformers
import torch
pipeline = transformers.pipeline(
    "text-generation",
    model="unsloth/phi-4-unsloth-bnb-4bit",
    model_kwargs={"torch_dtype": "auto"},
    device_map="auto",
)

messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "How should I explain the Internet?"},
]

outputs = pipeline(messages, max_new_tokens=128)
print(outputs[0]["generated_text"][-1])
# Out:
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# {'role': 'assistant', 'content': "Explaining the Internet can be approached in a way that is accessible and relatable, depending on the audience's level of understanding. Here’s a structured way to explain it:\n\n### Basic Explanation\n\n1. **Definition**: \n   - The Internet is a global network of computers and other devices connected together, allowing them to communicate and share information.\n\n2. **How It Works**:\n   - **Connections**: Devices like computers, smartphones, and servers are connected through a series of cables, wireless signals, and satellites.\n   - **Data Transfer**: Information is sent in small packets of data that travel across this network to reach their destination.\n\n"}

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
